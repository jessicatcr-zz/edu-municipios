# %%
# -*- coding: utf 8

from matplotlib import pyplot as plt

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('big_table.csv')
df
# Out:
#            REGIAO  COD UF  UF              NOME MUNIC  POP EST  \
# 0     3 - Sudeste      31  MG     Abadia dos Dourados     7059
# 1     3 - Sudeste      31  MG     Abadia dos Dourados     7059
# 2     3 - Sudeste      31  MG                  Abaeté    23611
# 3     3 - Sudeste      31  MG                  Abaeté    23611
# 4     3 - Sudeste      31  MG                  Abaeté    23611
# 5     3 - Sudeste      31  MG              Abre Campo    13733
# 6     3 - Sudeste      31  MG              Abre Campo    13733
# 7     3 - Sudeste      31  MG              Abre Campo    13733
# 8     3 - Sudeste      31  MG                 Acaiaca     4065
# 9     3 - Sudeste      31  MG                 Acaiaca     4065
# 10    3 - Sudeste      31  MG                 Açucena     9997
# 11    3 - Sudeste      31  MG                 Açucena     9997
# 12    3 - Sudeste      31  MG                Água Boa    14370
# 13    3 - Sudeste      31  MG                Água Boa    14370
# ...
