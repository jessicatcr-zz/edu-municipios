# %%
# -*- coding: utf 8

from matplotlib import pyplot as plt

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Base_Munic_2017_Pop.csv')

# %%
df
# Out:
#        CodMun            REGIAO  COD UF  UF                  NOME MUNIC  \
# 0     1100015         1 - Norte      11  RO        Alta Floresta DOeste
# 1     1100023         1 - Norte      11  RO                   Ariquemes
# 2     1100031         1 - Norte      11  RO                      Cabixi
# 3     1100049         1 - Norte      11  RO                      Cacoal
# 4     1100056         1 - Norte      11  RO                  Cerejeiras
# 5     1100064         1 - Norte      11  RO           Colorado do Oeste
# 6     1100072         1 - Norte      11  RO                  Corumbiara
# 7     1100080         1 - Norte      11  RO               Costa Marques
# 8     1100098         1 - Norte      11  RO              Espigão DOeste
# 9     1100106         1 - Norte      11  RO               Guajará-Mirim
# 10    1100114         1 - Norte      11  RO                        Jaru
# 11    1100122         1 - Norte      11  RO                   Ji-Paraná
# ...
