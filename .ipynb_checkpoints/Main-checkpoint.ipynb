# %%
# -*- coding: utf 8

from matplotlib import pyplot as plt

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('EduBas_Munic.csv')
df
# Out:
#        CodMun       REGIAO  COD_UF  UF              NOME_MUNIC  POP_EST  \
# 0     3100104  3 - Sudeste      31  MG     Abadia dos Dourados     7059
# 1     3100104  3 - Sudeste      31  MG     Abadia dos Dourados     7059
# 2     3100203  3 - Sudeste      31  MG                  Abaeté    23611
# 3     3100203  3 - Sudeste      31  MG                  Abaeté    23611
# 4     3100203  3 - Sudeste      31  MG                  Abaeté    23611
# 5     3100302  3 - Sudeste      31  MG              Abre Campo    13733
# 6     3100302  3 - Sudeste      31  MG              Abre Campo    13733
# 7     3100302  3 - Sudeste      31  MG              Abre Campo    13733
# 8     3100401  3 - Sudeste      31  MG                 Acaiaca     4065
# 9     3100401  3 - Sudeste      31  MG                 Acaiaca     4065
# 10    3100500  3 - Sudeste      31  MG                 Açucena     9997
# 11    3100500  3 - Sudeste      31  MG                 Açucena     9997
# ...

# %%
df.columns
# Out:
# Index(['CodMun', 'REGIAO', 'COD_UF', 'UF', 'NOME_MUNIC', 'POP_EST',
#        'CLASSE_POP', 'Barco', 'Metro', 'Mototx', 'Taxi', 'Trem', 'Van',
#        'Aviao', 'ImpacAmb_24meses', 'Secas_Enxurr', 'PoluiAr',
#        'Polui_corpoAgua', 'Assorea_corpoAgua', 'DiminVazao_corpoAgua',
#        'Desmatam', 'Queimad', 'Erosao_Desert', 'Dimin_FaunaFlora',
#        'MoradRiscoAmb', 'FaltaSaneamen', 'Favela', 'Cortico', 'Lote_Irr',
#        'Ocupacao', 'AtingidoPorSeca_4a', 'AtingidoPorAlagam_4a',
#        'AtingidoPorErosao_4a', 'AtingidoPorEnchente_4a',
#        'AtingidoPorEnxurrada_4a', 'AtingidoPorDeslizam_4a', 'Nome_Municipio',
#        'Rede', 'Taxa_Aprovacao_1-5 ', 'Taxa_Aprovacao_1', 'Taxa_Aprovacao_2',
#        'Taxa_Aprovacao_3', 'Taxa_Aprovacao_4', 'Taxa_Aprovacao_5',
#        'Indicador_Rendimento_P', 'Matemática', 'Língua_Portuguesa',
#        'Nota_Media_Padronizada_N', 'IDEB_N_x_P'],
#       dtype='object')

# %%
df = df[df.Rede != 'Pública'] #Pois é uma junção entre as outras (Municipal, Estadual e Federal)
#df['Rede']

# %% [markdown]
# ## Var para os municípios
# - Muito pequenos = MP: Até 5k
# - Pequenos = P: 5001 até 20k
# - Grandes = G: A partir de 100.001

# %%
dfMP = df[df['POP_EST'] <= 5000]
dfP = df[(df['POP_EST'] > 5000) & (df['POP_EST'] <= 20000)]
dfG = df[df['POP_EST'] > 100000]

# %%
filtroMP = dfMP['IDEB_N_x_P'] != '-'
dfMP_IDEB = dfMP[filtroMP]

filtroP = dfP['IDEB_N_x_P'] != '-'
dfP_IDEB = dfP[filtroP]

filtroG = dfG['IDEB_N_x_P'] != '-'
dfG_IDEB = dfG[filtroG]

maxMP_IDEB = dfMP_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).max()
minMP_IDEB = dfMP_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).min()
medianMP_IDEB = dfMP_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).median()
medMP_IDEB = dfMP_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).mean()

medP_IDEB = dfP_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).mean()
medG_IDEB = dfG_IDEB['IDEB_N_x_P'].apply(lambda x, axis:float(x), axis=1).mean()

print(maxMP_IDEB)
print(minMP_IDEB)
print(medianMP_IDEB)
print(medMP_IDEB)

print(medP_IDEB)
print(medG_IDEB)
# Out:
# 8.0
# 3.7
# 6.2
# 6.248878923766818
# 6.244243421052634
# 6.438805970149252

# %%
filtroMP_Mat = dfMP['IDEB_N_x_P'] != '-'
dfMP_Mat = dfMP[filtroMP_Mat]

filtroP_Mat = dfP['IDEB_N_x_P'] != '-'
dfP_Mat = dfP[filtroP_Mat]

filtroG_Mat = dfG['IDEB_N_x_P'] != '-'
dfG_Mat = dfG[filtroG_Mat]

medMP_Mat = dfMP_Mat['Matemática'].apply(lambda x, axis:float(x), axis=1).mean()
medP_Mat = dfP_Mat['Matemática'].apply(lambda x, axis:float(x), axis=1).mean()
medG_Mat = dfG_Mat['Matemática'].apply(lambda x, axis:float(x), axis=1).mean()

print(medMP_Mat)
print(medP_Mat)
print(medG_Mat)
# Out:
# 232.48739910313887
# 230.13860197368413
# 234.71507462686563

# %%
filtroMP_Port = dfMP['IDEB_N_x_P'] != '-'
dfMP_Port = dfMP[filtroMP_Port]

filtroP_Port = dfP['IDEB_N_x_P'] != '-'
dfP_Port = dfP[filtroP_Port]

filtroG_Port = dfG['IDEB_N_x_P'] != '-'
dfG_Port = dfG[filtroG_Port]

medMP_Port = dfMP_Port['Língua_Portuguesa'].apply(lambda x, axis:float(x), axis=1).mean()
medP_Port = dfP_Port['Língua_Portuguesa'].apply(lambda x, axis:float(x), axis=1).mean()
medG_Port = dfG_Port['Língua_Portuguesa'].apply(lambda x, axis:float(x), axis=1).mean()

print(medMP_Port)
print(medP_Port)
print(medG_Port)
# Out:
# 221.63434977578478
# 219.6740789473685
# 227.69552238805966
